# %% [markdown]
# # <center> **CSE 346 Data Science Lab Tasks** </center>
# ## <center>Naimul Hasan <center>
# ## <center>2017331059</center>

# %% [markdown]
# # <center>**Task 01**</center>
#
# ---

# %% [markdown]
# **DataFrame** is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input:
# *   Dict of 1D ndarrays, lists, dicts, or Series
# *   2-D numpy.ndarray
# *   Structured or record ndarray
# *   A Series
#
# Along with the data, you can optionally pass index (row labels) and columns (column labels) arguments. If you pass an index and / or columns, you are guaranteeing the index and / or columns of the resulting DataFrame. Thus, a dict of Series plus a specific index will discard all data not matching up to the passed index.
#
# If axis labels are not passed, they will be constructed from the input data based on common sense rules.

# %% [markdown]
# #### Importing Libraries
#
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Loading dataset
#
# ---

# %%
# load red and white wine datasets
red_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winequality-red.csv', sep=';')
white_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winequality-red.csv', sep=';')

#red_df.head() #inspect to check delimiter
red_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
#white_df.head() #inspect to check delimiter
white_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# **Create Color Columns**
#
# Create two arrays as long as the number of rows in the red and white dataframes that repeat the value “red” or “white.” NumPy offers really easy way to do this. Here’s the documentation for NumPy’s repeat function. Take a look and try it yourself.

# %%
# create color array for red dataframe
color_red = np.repeat('red', 1599)

# create color array for white dataframe
color_white = np.repeat('white', 1599)

# %% [markdown]
# Add arrays to the red and white dataframes. Do this by setting a new column called 'color' to the appropriate array. The cell below does this for the red dataframe.

# %%
red_df['color'] = color_red
red_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  color
# 0            7.4              0.70         0.00  ...      9.4        5    red
# 1            7.8              0.88         0.00  ...      9.8        5    red
# 2            7.8              0.76         0.04  ...      9.8        5    red
# 3           11.2              0.28         0.56  ...      9.8        6    red
# 4            7.4              0.70         0.00  ...      9.4        5    red
#
# [5 rows x 13 columns]

# %% [markdown]
# This cell do the same for the white dataframe and use head() to confirm the change.

# %%
white_df['color'] = color_white
white_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  color
# 0            7.4              0.70         0.00  ...      9.4        5  white
# 1            7.8              0.88         0.00  ...      9.8        5  white
# 2            7.8              0.76         0.04  ...      9.8        5  white
# 3           11.2              0.28         0.56  ...      9.8        6  white
# 4            7.4              0.70         0.00  ...      9.4        5  white
#
# [5 rows x 13 columns]

# %%
white_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
#  12  color                 1599 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 162.5+ KB

# %% [markdown]
# **Combine two csv files into a single csv file** <br>

# %%
# append dataframes
wine_df = pd.concat([red_df, white_df])

# view dataframe to check for success
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  color
# 0            7.4              0.70         0.00  ...      9.4        5    red
# 1            7.8              0.88         0.00  ...      9.8        5    red
# 2            7.8              0.76         0.04  ...      9.8        5    red
# 3           11.2              0.28         0.56  ...      9.8        6    red
# 4            7.4              0.70         0.00  ...      9.4        5    red
#
# [5 rows x 13 columns]

# %%
#inspect wine_df in details to verify concateation
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3198 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3198 non-null   float64
#  1   volatile acidity      3198 non-null   float64
#  2   citric acid           3198 non-null   float64
#  3   residual sugar        3198 non-null   float64
#  4   chlorides             3198 non-null   float64
#  5   free sulfur dioxide   3198 non-null   float64
#  6   total sulfur dioxide  3198 non-null   float64
#  7   density               3198 non-null   float64
#  8   pH                    3198 non-null   float64
#  9   sulphates             3198 non-null   float64
#  10  alcohol               3198 non-null   float64
#  11  quality               3198 non-null   int64
#  12  color                 3198 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 349.8+ KB

# %% [markdown]
# **Save Combined Dataset** <br>
# Save your newly combined dataframe as winequality_edited.csv. Remember, set index=False to avoid saving with an unnamed column!
#
# **Info about new Dataframe**
# *   How many rows are in the combined dataframe?
#     <br>Answer : 3198
# *   How many columns are in the combined dataframe? <br>
#     Answer : 13

# %%
# Details about the appended data set(combining two data sets in a single csv file)
wine_df.to_csv('/content/drive/MyDrive/Colab Notebooks/winequality_edited.csv', index=False)
df_new = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/winequality_edited.csv')
df_new.info()
print('Data table shape: ')
print(df_new.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3198 non-null   float64
#  1   volatile acidity      3198 non-null   float64
#  2   citric acid           3198 non-null   float64
#  3   residual sugar        3198 non-null   float64
#  4   chlorides             3198 non-null   float64
#  5   free sulfur dioxide   3198 non-null   float64
#  6   total sulfur dioxide  3198 non-null   float64
#  7   density               3198 non-null   float64
#  8   pH                    3198 non-null   float64
#  9   sulphates             3198 non-null   float64
#  10  alcohol               3198 non-null   float64
#  11  quality               3198 non-null   int64
#  12  color                 3198 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 324.9+ KB
# Data table shape:
# ...

# %% [markdown]
# ####Size of the data table
#
# ---

# %%
print("Shape of the dataset: ")
print(df_new.shape)
# Out:
# Shape of the dataset:
# (3198, 13)

# %% [markdown]
# ####Columns name
#
# ---

# %%
print('Columns name :')
print(df_new.columns)
# Out:
# Columns name :
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %% [markdown]
# ####Data types of the columns
#
# ---

# %%
print('Data types of the columns : ')
print(df_new.dtypes)
# Out:
# Data types of the columns :
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object

# %% [markdown]
# ####Handling NULL or missing values

# %%
print("Checking if there is any NULL values, if there is any then True will be printed otherwise we'll get False as output.")
print(df_new.isnull().values.any())
# df_new.isna()
print('\n')
df_new.isna().sum()
# Out:
# Checking if there is any NULL values, if there is any then True will be printed otherwise we'll get False as output.
# False
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %% [markdown]
# So there is no NULL value. In case if we get NULL value then we'll have to handle that case with MIN, MAX, 0 or AVG value.<br>
# **Missing** values will be checked by the below cell.

# %%
#To check missing values
sns.heatmap(df_new.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %% [markdown]
# *   Dataset has no missing values.
# *   If there were any, we would've noticed in figure represented by different colour shade on purple background.

# %% [markdown]
# ####Handling duplicate rows values
#
# ---

# %%
# Getting all the duplicated rows
df_new[df_new.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  color
# 4               7.4             0.700         0.00  ...      9.4        5    red
# 11              7.5             0.500         0.36  ...     10.5        5    red
# 27              7.9             0.430         0.21  ...      9.5        5    red
# 40              7.3             0.450         0.36  ...     10.5        5    red
# 65              7.2             0.725         0.05  ...     10.9        5    red
# ...             ...               ...          ...  ...      ...      ...    ...
# 3162            7.2             0.695         0.13  ...     10.1        5  white
# 3163            7.2             0.695         0.13  ...     10.1        5  white
# 3166            7.2             0.695         0.13  ...     10.1        5  white
# 3180            6.2             0.560         0.09  ...     11.3        5  white
# 3195            6.3             0.510         0.13  ...     11.0        6  white
#
# ...

# %%
# Droping the duplicated rows
df_new.drop_duplicates(keep='first',inplace=True)

# %%
# After dropping the duplicated rows
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  color
# 0               7.4             0.700         0.00  ...      9.4        5    red
# 1               7.8             0.880         0.00  ...      9.8        5    red
# 2               7.8             0.760         0.04  ...      9.8        5    red
# 3              11.2             0.280         0.56  ...      9.8        6    red
# 5               7.4             0.660         0.00  ...      9.4        5    red
# ...             ...               ...          ...  ...      ...      ...    ...
# 3192            6.8             0.620         0.08  ...      9.5        6  white
# 3193            6.2             0.600         0.08  ...     10.5        5  white
# 3194            5.9             0.550         0.10  ...     11.2        6  white
# 3196            5.9             0.645         0.12  ...     10.2        5  white
# 3197            6.0             0.310         0.47  ...     11.0        6  white
#
# ...

# %% [markdown]
# #### Get data only from a particular column
#
# ---

# %%
df_new.density
# Out:
# 0       0.99780
# 1       0.99680
# 2       0.99700
# 3       0.99800
# 5       0.99780
#          ...
# 3192    0.99651
# 3193    0.99490
# 3194    0.99512
# 3196    0.99547
# 3197    0.99549
# Name: density, Length: 2718, dtype: float64

# %% [markdown]
# ####Count different column values
#
# ---

# %%
df_new.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    2718.000000       2718.000000  ...  2718.000000  2718.000000
# mean        8.310596          0.529478  ...    10.432315     5.623252
# std         1.736670          0.182998  ...     1.081866     0.823426
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
df_new.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  ...  sulphates    alcohol
# quality                                   ...
# 3             8.360000          0.884500  ...   0.570000   9.955000
# 4             7.779245          0.693962  ...   0.596415  10.265094
# 5             8.171231          0.578596  ...   0.623570   9.888562
# 6             8.337383          0.496084  ...   0.674542  10.658879
# 7             8.858683          0.403653  ...   0.742635  11.491118
# 8             8.441176          0.427647  ...   0.774706  12.158824
#
# [6 rows x 11 columns]

# %% [markdown]
# #### To check correlation

# %%
sns.heatmap(df_new.corr(),cmap='Blues',annot=False) 
# Dark shades represents positive correlation while lighter shades represents negative correlation.

# %%
#Quality correlation matrix
k = 12 #number of variables for heatmap
cols = df_new.corr().nlargest(k, 'quality')['quality'].index
cm = df_new[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %% [markdown]
# Here we can infer that "density" has strong positive correlation with "residual sugar" whereas it has strong negative correlation with "alcohol".
# "free sulphur dioxide" and "citric acid" has almost no correlation with "quality"
# Since correlation is zero we can infer there is no linear relationship between these two predictors.However it is safe to drop these features in case you're applying Linear Regression model to the dataset.

# %% [markdown]
# #<center> **Task 02** </center>
#
# ---

# %% [markdown]
# #### Let us see how different factors seem to affect the quality

# %%
sns.countplot(df_new['quality'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_new['pH'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_new['alcohol'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_new['fixed acidity'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_new['volatile acidity'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_new['citric acid'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.countplot(df_new['density'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# KDE plot of quality
sns.kdeplot(df_new.query('quality > 2').quality)

# %%
sns.distplot(df_new['alcohol'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_new.plot(kind ='box',figsize=(15,12),subplots = True, layout =(6,2),sharex = False)
# Out:
# fixed acidity              AxesSubplot(0.125,0.772143;0.352273x0.107857)
# volatile acidity        AxesSubplot(0.547727,0.772143;0.352273x0.107857)
# citric acid                AxesSubplot(0.125,0.642714;0.352273x0.107857)
# residual sugar          AxesSubplot(0.547727,0.642714;0.352273x0.107857)
# chlorides                  AxesSubplot(0.125,0.513286;0.352273x0.107857)
# free sulfur dioxide     AxesSubplot(0.547727,0.513286;0.352273x0.107857)
# total sulfur dioxide       AxesSubplot(0.125,0.383857;0.352273x0.107857)
# density                 AxesSubplot(0.547727,0.383857;0.352273x0.107857)
# pH                         AxesSubplot(0.125,0.254429;0.352273x0.107857)
# sulphates               AxesSubplot(0.547727,0.254429;0.352273x0.107857)
# alcohol                       AxesSubplot(0.125,0.125;0.352273x0.107857)
# quality                    AxesSubplot(0.547727,0.125;0.352273x0.107857)
# dtype: object

# %%
df_new.plot(kind ='density', figsize=(15,12),subplots = True, layout =(6,2),sharex = False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1948c5e50>,
# ...
#       dtype=object)

# %%
df_new.hist(figsize=(15,12),bins=50, color='#3F5D7D')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb194858710>,
# ...
#       dtype=object)

# %%
sns.pairplot(df_new)

# %% [markdown]
# # <center>**Task 03**</center>
#
# ---

# %% [markdown]
# Coming to training the model for Wine Quality Prediction we will be first pre-processing the data and then running 3 different models on the dataset to single out the best result. The models are as follows:
#
#
# *   Simple Linear Regression
# *   Multiple Linear Regression
# *   Polynomial Linear Regression

# %% [markdown]
# ### Spliting the dataset into train and test and preparing the dataset

# %%
X = df_new.iloc[:, :-1].values
y = df_new.iloc[:, -1].values
# Out:
# [[ 7.4    0.7    0.    ...  0.56   9.4    5.   ]
#  [ 7.8    0.88   0.    ...  0.68   9.8    5.   ]
#  [ 7.8    0.76   0.04  ...  0.65   9.8    5.   ]
#  ...
#  [ 5.9    0.55   0.1   ...  0.76  11.2    6.   ]
#  [ 5.9    0.645  0.12  ...  0.71  10.2    5.   ]
#  [ 6.     0.31   0.47  ...  0.66  11.     6.   ]]
# ['red' 'red' 'red' ... 'white' 'white' 'white']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ### Model 1 : Simple Linear Regression

# %%
X = df_new['alcohol'].values
y = df_new['quality'].values

# %%
# Plot scatter plot between X and y

plt.scatter(X, y, color = 'blue', label='Scatter Plot')
plt.title('Relationship between Alcohol and Quality')
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.legend(loc=4)
plt.show()

# %%
# Print the dimensions of X and y

print(X.shape)
print(y.shape)
# Out:
# (2718, 1)
# (2718, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.3, random_state=5)

# %%
# Print the dimensions of X_train,X_test,y_train,y_test

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1902, 1)
# (1902, 1)
# (816, 1)
# (816, 1)

# %%
# Fit the linear model

# Instantiate the linear regression object lm
from sklearn.linear_model import LinearRegression
lm = LinearRegression()


# Train the model using training data sets
lm.fit(X_train,y_train)


# Predict on the test data
y_pred=lm.predict(X_test)

# %%
# Compute model slope and intercept

a = lm.coef_
b = lm.intercept_,
print("Estimated model slope, a:" , a)
print("Estimated model intercept, b:" , b)
# Out:
# Estimated model slope, a: [[0.35661049]]
# Estimated model intercept, b: (array([1.90397113]),)

# %%
# Calculate and print Root Mean Square Error(RMSE)

from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE value: {:.4f}".format(rmse))
# Out:
# RMSE value: 0.6919

# %%
# Calculate and print r2_score

from sklearn.metrics import r2_score
print ("R2 Score value: {:.4f}".format(r2_score(y_test, y_pred)))
# Out:
# R2 Score value: 0.2612

# %%
# Plot the Regression Line


plt.scatter(X, y, color = 'blue', label='Scatter Plot')
plt.plot(X_test, y_pred, color = 'black', linewidth=3, label = 'Regression Line')
plt.title('Relationship between Sales and Advertising')
plt.xlabel('Sales')
plt.ylabel('Advertising')
plt.legend(loc=4)
plt.show()

# %%
# Plotting residual errors

plt.scatter(lm.predict(X_train), lm.predict(X_train) - y_train, color = 'red', label = 'Train data')
plt.scatter(lm.predict(X_test), lm.predict(X_test) - y_test, color = 'blue', label = 'Test data')
plt.hlines(xmin = 0, xmax = 50, y = 0, linewidth = 3)
plt.title('Residual errors')
plt.legend(loc = 4)
plt.show()

# %%
# Checking for Overfitting or Underfitting the data

print("Training set score: {:.4f}".format(lm.score(X_train,y_train)))

print("Test set score: {:.4f}".format(lm.score(X_test,y_test)))
# Out:
# Training set score: 0.2182
# Test set score: 0.2612

# %% [markdown]
# ### Model 2: Multiple Linear Regression

# %%
# Train model on whole dataset
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
regressor = LinearRegression()
regressor.fit(x_train,y_train)

#Predicting Test Set Results
y_pred = regressor.predict(x_test)

# Evaluating Model Performance
r2_score(y_test,y_pred)

# %% [markdown]
# ### Model 3: Polynomial Linear Regression

# %%
from sklearn.preprocessing import PolynomialFeatures 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import r2_score
poly_reg = PolynomialFeatures(degree = 4) 
x_poly = poly_reg.fit_transform(x_train2) 
lin_reg_2 = LinearRegression() lin_reg_2.fit(x_poly,y)

#Predicting Test Set Results
y_pred2 = lin_reg_2.predict(poly_reg.transform(x_test2))

# Evaluating Model Performance
r2_score(y_test2,y_pred2)

# %% [markdown]
# Out of the 11 features we examined, the top 3 significant features that help the vintner brew a delicious Red Wine are low levels of sulfur dioxide, and high levels of sulphates & alcohol.
# Our Random Forest algorithm yields the highest R² value, 83%! Any R² above 70% is considered good, but be careful because if your accuracy is extremely high, it may be too good to be true (an example of Over fitting). Thus, 83% is the ideal accuracy!
# Our machine learning algorithm can now predict the red wine quality given its ratio of ingredients. By detecting these important features, we may prevent our vintner from going out of business or losing any profit! Making a wine that no one will enjoy is costly and will lose revenue for our company. This is tremendously powerful because now we can properly see which components of wine people prefer & thus maximize our profit!
