# %%
import pandas as pd
import numpy as np 
import scipy 
import sklearn 
import seaborn as sns
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# <h1 align='center'> Task 1 </h1>

# %% [markdown]
#  DataFrame: DataFrame is a 2-dimensional labeled data structure with columns of potentially different types.

# %%
df=pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Data only from column

# %% [markdown]
# Counting different column values

# %% [markdown]
# <h2 align='center'> Task 2</h2>

# %% [markdown]
# Contents of the dataset: This data set consists of three types of entities: (a) the specification of an auto in terms of various characteristics, (b) its assigned insurance risk rating, (c) its normalized losses in use as compared to other cars. The second rating corresponds to the degree to which the auto is more risky than its price indicates. Cars are initially assigned a risk factor symbol associated with its price. Then, if it is more risky (or less), this symbol is adjusted by moving it up (or down) the scale. Actuarians call this process "symboling". A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.
#
# The third factor is the relative average loss payment per insured vehicle year. This value is normalized for all autos within a particular size classification (two-door small, station wagons, sports/speciality, etc...), and represents the average loss per car per year.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.drop_duplicates(subset=['pH'],inplace=True)
df.shape
# Out:
# (89, 12)

# %%
fig, ax = plt.subplots(ncols = 2, nrows = 6, figsize = (30, 40), squeeze=False)
index = 0
ax = ax.flatten()

for col in list(df.columns):
    sns.distplot(df[col], ax=ax[index], rug=True, rug_kws={"color": "g"},

                  kde_kws={"color": "k", "lw": 3, "label": "KDE"},

                  hist_kws={"histtype": "step", "linewidth": 3,

                            "alpha": 1, "color": "g"})
    index += 1

plt.draw()
# Out:
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize = (20,20))
for i,col in enumerate(df.drop('quality',axis =1).columns):
    plt.subplot(4,3,i+1)
    sns.boxplot(y = col, x = 'quality',data = df,palette="husl")
plt.show()

# %% [markdown]
# Removing Outliers in the Data

# %%
sns.boxplot(df['pH'],color='purple')
plt.title("Box Plot before outlier removal")
plt.show()
df['pH'],fitted_lambda= scipy.stats.boxcox(df['pH'] ,lmbda=None)
sns.boxplot(df['pH'],color='red')
plt.title("Box Plot after outlier removal")
plt.show()
# Out:
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df,palette="Set1",hue='quality')
# Out:
# Error in callback <function flush_figures at 0x7faa80dfd310> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# Scaling Using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()



df[['total sulfur dioxide', 'free sulfur dioxide']] = scaler.fit_transform(df[['total sulfur dioxide', 'free sulfur dioxide']].to_numpy())

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.shape
# Out:
# (1359, 11)

# %% [markdown]
# This dataset is suitable for supervised learning.
#
#  The Features are :  fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH, sulphates, alcohol
#
#  The Response Variable is :  quality (score between 0 and 10)

# %% [markdown]
# <h5 bgcolor='yellow'> Significant Features </h5>

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.inspection import permutation_importance

model = KNeighborsRegressor()
# fit the model
model.fit(X, y)
results = permutation_importance(model, X, y, scoring='neg_mean_squared_error')

importance = results.importances_mean

for i,v in enumerate(importance):
	print('Feature Name: %s, Score: %.7f' % (X.columns[i],v))

plt.figure(figsize=(17,8))
plt.bar([X.columns[x] for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature Name: fixed acidity, Score: 0.1856483
# Feature Name: volatile acidity, Score: 0.0217277
# Feature Name: citric acid, Score: 0.0002884
# Feature Name: residual sugar, Score: 0.0752259
# Feature Name: chlorides, Score: 0.0006358
# Feature Name: free sulfur dioxide, Score: 0.1111405
# Feature Name: total sulfur dioxide, Score: 0.1116586
# Feature Name: density, Score: 0.0000000
# Feature Name: pH, Score: 0.0003414
# Feature Name: sulphates, Score: 0.0088771
# Feature Name: alcohol, Score: 0.3786608

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split 



X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %% [markdown]
# <h1 align='center'> Task 3 </h1>

# %% [markdown]
# Question : What will be the price given all the input columns ?

# %%
Error_dict={}

# %%
from sklearn import linear_model

lasso_regressor= linear_model.Lasso(alpha=0.1)
lasso_regressor.fit(X_train,y_train)

y_pred=lasso_regressor.predict(X_test)

Error_dict['lasso_r_squared_value']=r2_score(y_test,y_pred)

plt.scatter(y_test,y_pred)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
# Out:
# Text(0, 0.5, 'Predicted values')

# %%
ridge_regressor= linear_model.Ridge()
ridge_regressor.fit(X_train,y_train)

y_pred=ridge_regressor.predict(X_test)

Error_dict['ridge_r_squared_value']=r2_score(y_test,y_pred)

plt.scatter(y_test,y_pred)
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
# Out:
# Text(0, 0.5, 'Predicted values')

# %%
from sklearn.svm import SVR 

svm_linear = SVR(kernel='linear')
svm_poly = SVR(kernel='poly')
svm_rbf= SVR(kernel='rbf')

svm_linear.fit(X_train,y_train)
svm_poly.fit(X_train,y_train)
svm_rbf.fit(X_train,y_train)

y_pred=svm_linear.predict(X_test)


Error_dict['svm_linear_r_squared_value']=r2_score(y_test,y_pred)


y_pred=svm_poly.predict(X_test)

Error_dict['svm_poly_r_squared_value']=r2_score(y_test,y_pred)
y_pred=svm_rbf.predict(X_test)

rbf_svm_r_squared_value = r2_score(y_test,y_pred)
Error_dict['svm_rbf_r_squared_value']=r2_score(y_test,y_pred)

# %%
Error_dict
# Out:
# {'lasso_r_squared_value': 0.246545547476408,
#  'ridge_r_squared_value': 0.3686807377083785,
#  'svm_linear_r_squared_value': 0.363251501614565,
#  'svm_poly_r_squared_value': 0.34152604058952607,
#  'svm_rbf_r_squared_value': 0.3182556940470196}

# %% [markdown]
# Taking Top 5 Features

# %%
X_short=X[['fixed acidity','alcohol','total sulfur dioxide','free sulfur dioxide','residual sugar']]

# %%
X_short.shape
# Out:
# (1359, 5)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_short,y,test_size=0.2,random_state=32)

# %%
Error_dict_5features={}

# %%
ridge_regressor= linear_model.Ridge()
ridge_regressor.fit(X_train,y_train)

y_pred=ridge_regressor.predict(X_test)

ridge_r_squared_value = r2_score(y_test,y_pred)
Error_dict_5features['ridge_r_squared_value']=r2_score(y_test,y_pred)

# %%
lasso_regressor= linear_model.Lasso(alpha=0.1)
lasso_regressor.fit(X_train,y_train)

y_pred=lasso_regressor.predict(X_test)

Error_dict_5features['lasso_r_squared_value']=r2_score(y_test,y_pred)

# %%
from sklearn.svm import SVR 


svm_linear = SVR(kernel='linear')
svm_poly = SVR(kernel='poly')
svm_rbf= SVR(kernel='rbf')

svm_linear.fit(X_train,y_train)
svm_poly.fit(X_train,y_train)
svm_rbf.fit(X_train,y_train)

y_pred=svm_linear.predict(X_test)


Error_dict_5features['svm_linear_r_squared_value']=r2_score(y_test,y_pred)


y_pred=svm_poly.predict(X_test)

Error_dict_5features['svm_poly_r_squared_value']=r2_score(y_test,y_pred)
y_pred=svm_rbf.predict(X_test)

rbf_svm_r_squared_value = r2_score(y_test,y_pred)
Error_dict_5features['svm_rbf_r_squared_value']=r2_score(y_test,y_pred)

# %%
Error_dict_5features
# Out:
# {'ridge_r_squared_value': 0.17855632615144024,
#  'lasso_r_squared_value': 0.15473494245324926,
#  'svm_linear_r_squared_value': 0.17381856780973004,
#  'svm_poly_r_squared_value': 0.19149854679731948,
#  'svm_rbf_r_squared_value': 0.1932290093166693}

# %% [markdown]
# Before and After Taking 5 most important features

# %%
plt.figure(figsize=(12,6))
sns.barplot(list(Error_dict.keys()),list(Error_dict.values()))
plt.title("Before")
# Out:
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Before')

# %%
plt.figure(figsize=(12,6))
sns.barplot(list(Error_dict_5features.keys()),list(Error_dict_5features.values()))
plt.title("After")
# Out:
# /home/joy/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'After')

# %% [markdown]
# <h3> Interpreting the Result:  </h3>
#
# When taking all the 11 features into consideration, the r2 score was high (i.e the result was good)
#
# After modifying the train dataframe, and taking 5 topmost impactful features into consideration, the r2 score was a bit lowered.
#
# Among the 5 models that we trained on the train set, Ridge regressor and SVM Regressor with Linear Kernel performed the best.

# %% [markdown]
# <h3> Conclusion : </h3>
#
# The highest r squared value acheived by our best model is 0.37843 ( By Ridge Regressor Model )
#
# The most important features to estimate the quality of red wine are :
#
# 1. Alcohol
# 2. Fixed Acidity
# 3. Free Sulfur Dioxide
# 4. Total Sulfur Dioxide
# 5. Residual Sugar
