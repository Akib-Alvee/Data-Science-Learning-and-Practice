# %%
import nltk

from gensim.models import Word2Vec
from nltk.corpus import stopwords

import re

# %%
with open('text.txt') as f:
    data = f.readlines()
    
data = str(data)
print(type(data))
# Out:
# <class 'str'>

# %%
text = re.sub(r'\[[0-9]*\]',' ',data)
text = re.sub(r'\s+',' ',text)
text = text.lower()
text = re.sub(r'\d',' ',text)
text = re.sub(r'\s+',' ',text)
text
# Out:
# '["the student protest at shahjalal university of science and technology (sust) in sylhet demanding vice chancellor prof farid uddin ahmed’s removal apparently had no solution in sight as of yesterday.sust students have been protesting, initially only demanding the resignation of zafrin ahmed, provost of begum sirajunnesa chowdhury hall that turned into the one-point demand of removing the vc. at a stage they went into a fast unto death movement, which is still going on amid pressure from different quarters.it all started on the night of january . students claimed that the hall’s residents called the provost over the phone to talk about some issues, including the misbehavior of the hall’s security guards. zafrin ahmed allegedly misbehaved with them. that night female students started a demonstration in front of the hall at around : pm. the demonstration later moved to the vc’s quarters. the students had two demands—removal of zafrin ahmed and other assistant provosts and an apology. the vc talked to them and scheduled a discussion the next day at his office. on january , a delegation of the students had a meeting with the vc at his office with demands, including eliminating all mismanagement of the hall immediately to ensure a healthy and normal environment and immediately appointing a student-friendly and responsible presiding committee.the students continued a sit-in in front of the vc’s office. in the afternoon they issued an ultimatum till saturday evening, calling for the removal of the provost. they halted their movement, expecting the demands to be met. the sust authorities that afternoon appointed assistant provost zobaida kanak khan as the acting provost but the students were not satisfied.on january , they took to the streets again even as the authorities requested them to go back to the halls. in the evening, while the university proctor went to the students and requested them to leave the streets, activists of the chhatra league allegedly swooped on the students and activists of some left-leaning student organizations.the next day female students took to the streets again protesting the attack. some students from other halls joined them. they announced a boycott of all classes and examinations until all demands were met.on the day, leaders of the teachers’ association, heads of departments and proctor talked to the students and announced that they would accept the demands, and sought a week’s time for implementation of the demands. but the students rejected the overture and wanted the demands to be met at once.the vc was confronted by them as he was going to attend a meeting of deans. teachers and officials cordoned him off and took him to the ict bhaban. students locked the building’s gate. police and students were soon locked in clashes when the latter turned up to rescue the vc. students said a number of them were injured when the police wielded batons on them.police action on the campus drew much criticism across the country.that night the university was declared closed indefinitely and students were asked to leave the dormitories by noon the next day. on january new three-point demands were announced, including the vc’s resignation, public apology from the vc for ordering police action against students, and ensuring accountability of all involved in the attack on students. the students also declared the vc persona non grata on the campus. police filed a case against over unnamed students.the next day the students issued an ultimatum to the vc to resign by noon on jan and announced a fast unto death program if vc was not removed. on january twenty-four students went on a hunger strike unto death in front of the vc’s residence.meanwhile, an audio clip of the vc, in which he was heard making derogatory comments about the female students of jahangirnagar university, was disseminated.on january , five students were hospitalized and nine fell sick, teachers asked students to sit for a discussion, students refused to ...

# %%
sentences = nltk.sent_tokenize(text)

sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
for i in range(len(sentences)):
    sentences[i] = [word for word in sentences[i] if word not in stopwords.words('english')]

# %%
sentences
# Out:
# [['[',
#   '``',
#   'student',
#   'protest',
#   'shahjalal',
#   'university',
#   'science',
#   'technology',
#   '(',
#   'sust',
#   ')',
#   'sylhet',
#   'demanding',
#   'vice',
#   'chancellor',
#   'prof',
#   'farid',
#   'uddin',
#   'ahmed',
#   '’',
#   'removal',
#   'apparently',
#   'solution',
#   'sight',
#   'yesterday.sust',
#   'students',
#   'protesting',
#   ',',
#   'initially',
#   'demanding',
#   'resignation',
#   'zafrin',
#   'ahmed',
#   ',',
#   'provost',
#   'begum',
#   'sirajunnesa',
#   'chowdhury',
#   'hall',
#   'turned',
#   'one-point',
#   'demand',
#   'removing',
#   'vc',
#   '.'],
#  ['stage',
#   'went',
#   'fast',
#   'unto',
#   'death',
#   'movement',
#   ',',
#   'still',
#   'going',
#   'amid',
#   'pressure',
#   'different',
#   'quarters.it',
#   'started',
#   'night',
#   'january',
#   '.'],
#  ['students',
#   'claimed',
#   'hall',
#   '’',
#   'residents',
#   'called',
#   'provost',
#   'phone',
#   'talk',
#   'issues',
#   ',',
#   'including',
#   'misbehavior',
#   'hall',
#   '’',
#   'security',
#   'guards',
#   '.'],
#  ['zafrin', 'ahmed', 'allegedly', 'misbehaved', '.'],
#  ['night',
#   'female',
#   'students',
#   'started',
#   'demonstration',
#   'front',
#   'hall',
#   'around',
#   ':',
#   'pm',
#   '.'],
#  ['demonstration', 'later', 'moved', 'vc', '’', 'quarters', '.'],
#  ['students',
#   'two',
#   'demands—removal',
#   'zafrin',
#   'ahmed',
#   'assistant',
#   'provosts',
#   'apology',
#   '.'],
#  ['vc', 'talked', 'scheduled', 'discussion', 'next', 'day', 'office', '.'],
#  ['january',
#   ',',
#   'delegation',
#   'students',
#   'meeting',
#   'vc',
#   'office',
#   'demands',
#   ',',
#   'including',
#   'eliminating',
#   'mismanagement',
#   'hall',
#   'immediately',
#   'ensure',
#   'healthy',
#   'normal',
#   'environment',
#   'immediately',
#   'appointing',
#   'student-friendly',
#   'responsible',
#   'presiding',
#   'committee.the',
#   'students',
#   'continued',
#   'sit-in',
#   'front',
#   'vc',
#   '’',
#   'office',
#   '.'],
#  ['afternoon',
#   'issued',
#   'ultimatum',
#   'till',
#   'saturday',
#   'evening',
#   ',',
#   'calling',
#   'removal',
#   'provost',
#   '.'],
#  ['halted', 'movement', ',', 'expecting', 'demands', 'met', '.'],
#  ['sust',
#   'authorities',
#   'afternoon',
#   'appointed',
#   'assistant',
#   'provost',
#   'zobaida',
#   'kanak',
#   'khan',
#   'acting',
#   'provost',
#   'students',
#   'satisfied.on',
#   'january',
#   ',',
#   'took',
#   'streets',
#   'even',
#   'authorities',
#   'requested',
#   'go',
#   'back',
#   'halls',
#   '.'],
#  ['evening',
#   ',',
#   'university',
#   'proctor',
#   'went',
#   'students',
#   'requested',
#   'leave',
#   'streets',
#   ',',
#   'activists',
#   'chhatra',
#   'league',
#   'allegedly',
#   'swooped',
#   'students',
#   'activists',
#   'left-leaning',
#   'student',
#   'organizations.the',
#   'next',
#   'day',
#   'female',
#   'students',
#   'took',
#   'streets',
#   'protesting',
#   'attack',
#   '.'],
#  ['students', 'halls', 'joined', '.'],
#  ['announced',
#   'boycott',
#   'classes',
#   'examinations',
#   'demands',
#   'met.on',
#   'day',
#   ',',
#   'leaders',
#   'teachers',
#   '’',
#   'association',
#   ',',
#   'heads',
#   'departments',
#   'proctor',
#   'talked',
#   'students',
#   'announced',
#   'would',
#   'accept',
#   'demands',
#   ',',
#   'sought',
#   'week',
#   '’',
#   'time',
#   'implementation',
#   'demands',
#   '.'],
#  ['students',
#   'rejected',
#   'overture',
#   'wanted',
#   'demands',
#   'met',
#   'once.the',
#   'vc',
#   'confronted',
#   'going',
#   'attend',
#   'meeting',
#   'deans',
#   '.'],
#  ['teachers', 'officials', 'cordoned', 'took', 'ict', 'bhaban', '.'],
#  ['students', 'locked', 'building', '’', 'gate', '.'],
#  ['police',
#   'students',
#   'soon',
#   'locked',
#   'clashes',
#   'latter',
#   'turned',
#   'rescue',
#   'vc',
#   '.'],
#  ['students',
#   'said',
#   'number',
#   'injured',
#   'police',
#   'wielded',
#   'batons',
#   'them.police',
#   'action',
#   'campus',
#   'drew',
#   'much',
#   'criticism',
#   'across',
#   'country.that',
#   'night',
#   'university',
#   'declared',
#   'closed',
#   'indefinitely',
#   'students',
#   'asked',
#   'leave',
#   'dormitories',
#   'noon',
#   'next',
#   'day',
#   '.'],
#  ['january',
#   'new',
#   'three-point',
#   'demands',
#   'announced',
#   ',',
#   'including',
#   'vc',
#   '’',
#   'resignation',
#   ',',
#   'public',
#   'apology',
#   'vc',
#   'ordering',
#   'police',
#   'action',
#   'students',
#   ',',
#   'ensuring',
#   'accountability',
#   'involved',
#   'attack',
#   'students',
#   '.'],
#  ['students',
#   'also',
#   'declared',
#   'vc',
#   'persona',
#   'non',
#   'grata',
#   'campus',
#   '.'],
#  ['police',
#   'filed',
#   'case',
#   'unnamed',
#   'students.the',
#   'next',
#   'day',
#   'students',
#   'issued',
#   'ultimatum',
#   'vc',
#   'resign',
#   'noon',
#   'jan',
#   'announced',
#   'fast',
#   'unto',
#   'death',
#   'program',
#   'vc',
#   'removed',
#   '.'],
#  ['january',
#   'twenty-four',
#   'students',
#   'went',
#   'hunger',
#   'strike',
#   'unto',
#   'death',
#   'front',
#   'vc',
#   '’',
#   'residence.meanwhile',
#   ',',
#   'audio',
#   'clip',
#   'vc',
#   ',',
#   'heard',
#   'making',
#   'derogatory',
#   'comments',
#   'female',
#   'students',
#   'jahangirnagar',
#   'university',
#   ',',
#   'disseminated.on',
#   'january',
#   ',',
#   'five',
#   'students',
#   'hospitalized',
#   'nine',
#   'fell',
#   'sick',
#   ',',
#   'teachers',
#   'asked',
#   'students',
#   'sit',
#   'discussion',
#   ',',
#   'students',
#   'refused',
#   'talk',
#   'urged',
#   'teachers',
#   'join',
#   'cause.the',
#   'jahangirnagar',
#   'university',
#   'teachers',
#   "'",
#   'association',
#   'today',
#   'protested',
#   'sust',
#   'vc',
#   'making',
#   'offensive',
#   'remarks',
#   'female',
#   'students',
#   'ju',
#   ',',
#   'demanding',
#   'publicly',
#   'apologize',
#   'withdraw',
#   'indecent',
#   'remarks.on',
#   'january',
#   ',',
#   'education',
#   'minister',
#   'video',
#   'call',
#   'urged',
#   'five',
#   'protesters',
#   'meet',
#   'talks',
#   'dhaka',
#   '.'],
#  ['next',
#   'day',
#   'education',
#   'minister',
#   'dipu',
#   'moni',
#   'met',
#   'five-member',
#   'delegation',
#   'sust',
#   'teachers',
#   '.'],
#  ['said',
#   'issue',
#   'would',
#   'resolved',
#   'discussions',
#   'students.the',
#   'next',
#   'day',
#   'education',
#   'minister',
#   'dr',
#   'dipu',
#   'moni',
#   'virtual',
#   'meeting',
#   'protesting',
#   'students',
#   ',',
#   'requesting',
#   'submit',
#   'complaints',
#   'written',
#   'form',
#   'breaking',
#   'fast',
#   '.'],
#  ['one-hour', 'long', 'meeting', 'ended', 'without', 'outcome', '.'],
#  ['students',
#   'said',
#   'would',
#   'come',
#   'back',
#   'discussion',
#   'fellow',
#   'students',
#   'next',
#   'day',
#   'meeting',
#   'held',
#   'students',
#   'adamant',
#   'one-point',
#   'demand',
#   'removing',
#   'vc',
#   '.'],
#  ['took',
#   'position',
#   'front',
#   'vc',
#   "'s",
#   'residence',
#   ',',
#   'allowing',
#   'law',
#   'enforcement',
#   'media',
#   'personnel',
#   'enter',
#   'house',
#   '.'],
#  ['electricity',
#   'connection',
#   'vc',
#   '’',
#   'official',
#   'residence',
#   'severed',
#   'students',
#   'reconnected',
#   'hours.the',
#   'sust',
#   'teachers',
#   "'",
#   'association',
#   'urged',
#   'government',
#   'take',
#   'steps',
#   'regarding',
#   'vc',
#   'farid',
#   '’',
#   'resignation',
#   ',',
#   'meet',
#   'demands',
#   'students.on',
#   'january',
#   ',',
#   'sust',
#   'vc',
#   'apologized',
#   'jahangirnagar',
#   'university',
#   'students',
#   'teachers',
#   'remarks',
#   'female',
#   'students',
#   'ju.on',
#   'january',
#   ',',
#   'mobile',
#   'banking',
#   'numbers',
#   'current',
#   'former',
#   'sust',
#   'students',
#   'used',
#   'receive',
#   'financial',
#   'assistance',
#   'ongoing',
#   'protest',
#   'stopped',
#   'working',
#   ',',
#   'alleged',
#   'students',
#   '.'],
#  ['medical',
#   'team',
#   'sylhet',
#   'mag',
#   'osmani',
#   'medical',
#   'college',
#   'hospital',
#   'discontinued',
#   'services',
#   'agitating',
#   'students.\\n',
#   "''",
#   ']']]

# %%
model = Word2Vec(sentences, min_count=1)
words = list(model.wv.index_to_key)

# %%
words
# Out:
# ['students',
#  ',',
#  '.',
#  'vc',
#  '’',
#  'january',
#  'day',
#  'demands',
#  'teachers',
#  'sust',
#  'next',
#  'university',
#  'hall',
#  'provost',
#  'meeting',
#  'female',
#  'announced',
#  'police',
#  'ahmed',
#  'front',
#  'took',
#  'jahangirnagar',
#  'discussion',
#  'education',
#  'minister',
#  'urged',
#  'would',
#  'went',
#  'death',
#  'met',
#  'unto',
#  'said',
#  'night',
#  'office',
#  'streets',
#  'including',
#  'fast',
#  'zafrin',
#  'resignation',
#  'demanding',
#  'protesting',
#  'association',
#  'farid',
#  'afternoon',
#  'dipu',
#  'allegedly',
#  'meet',
#  'sylhet',
#  'demonstration',
#  'ultimatum',
#  'medical',
#  'issued',
#  'five',
#  'protest',
#  'declared',
#  'campus',
#  'remarks',
#  'student',
#  'asked',
#  'authorities',
#  "'",
#  'assistant',
#  'noon',
#  'students.the',
#  'apology',
#  'moni',
#  'talked',
#  'turned',
#  'proctor',
#  'one-point',
#  'demand',
#  'removing',
#  'activists',
#  'residence',
#  'locked',
#  'immediately',
#  'movement',
#  'leave',
#  'going',
#  'halls',
#  'back',
#  'started',
#  'attack',
#  'making',
#  'removal',
#  'requested',
#  'delegation',
#  'evening',
#  'talk',
#  'action',
#  'calling',
#  'saturday',
#  'halted',
#  'till',
#  'expecting',
#  ']',
#  'appointed',
#  'zobaida',
#  'heads',
#  'leaders',
#  'met.on',
#  'examinations',
#  'classes',
#  'boycott',
#  'joined',
#  'organizations.the',
#  'left-leaning',
#  'swooped',
#  'league',
#  'chhatra',
#  'continued',
#  'go',
#  'even',
#  'satisfied.on',
#  'acting',
#  'khan',
#  'kanak',
#  'sit-in',
#  'quarters',
#  'committee.the',
#  'sight',
#  'quarters.it',
#  'different',
#  'pressure',
#  'amid',
#  'still',
#  'stage',
#  'chowdhury',
#  'sirajunnesa',
#  'begum',
#  'initially',
#  'yesterday.sust',
#  'solution',
#  'presiding',
#  'apparently',
#  'uddin',
#  'prof',
#  'chancellor',
#  'vice',
#  ')',
#  '(',
#  'technology',
#  'science',
#  'shahjalal',
#  '``',
#  'claimed',
#  'residents',
#  'called',
#  'phone',
#  'responsible',
#  'student-friendly',
#  'appointing',
#  'environment',
#  'normal',
#  'healthy',
#  'ensure',
#  'mismanagement',
#  'eliminating',
#  'scheduled',
#  'provosts',
#  'demands—removal',
#  'two',
#  'moved',
#  'later',
#  'pm',
#  ':',
#  'around',
#  'misbehaved',
#  'guards',
#  'security',
#  'misbehavior',
#  'issues',
#  'departments',
#  'deans',
#  'accept',
#  'form',
#  'one-hour',
#  'long',
#  'ended',
#  'without',
#  'outcome',
#  'come',
#  'fellow',
#  'held',
#  'adamant',
#  'position',
#  "'s",
#  'allowing',
#  'law',
#  'enforcement',
#  'media',
#  'breaking',
#  'written',
#  'enter',
#  'complaints',
#  'indecent',
#  'remarks.on',
#  'video',
#  'call',
#  'protesters',
#  'talks',
#  'dhaka',
#  'five-member',
#  'issue',
#  'resolved',
#  'discussions',
#  'dr',
#  'virtual',
#  'requesting',
#  'submit',
#  'personnel',
#  'house',
#  'apologize',
#  'used',
#  'financial',
#  'assistance',
#  'ongoing',
#  'stopped',
#  'working',
#  'alleged',
#  'team',
#  'mag',
#  'osmani',
#  'college',
#  'hospital',
#  'discontinued',
#  'services',
#  'agitating',
#  'students.\\n',
#  'receive',
#  'former',
#  'electricity',
#  'current',
#  'connection',
#  'official',
#  'severed',
#  'reconnected',
#  'hours.the',
#  'government',
#  'take',
#  'steps',
#  'regarding',
#  'students.on',
#  'apologized',
#  'ju.on',
#  'mobile',
#  'banking',
#  'numbers',
#  'withdraw',
#  'publicly',
#  'sought',
#  'clashes',
#  'rescue',
#  'number',
#  'injured',
#  'wielded',
#  'batons',
#  'them.police',
#  'drew',
#  'much',
#  'criticism',
#  'across',
#  'country.that',
#  'closed',
#  'indefinitely',
#  'dormitories',
#  'new',
#  'latter',
#  'soon',
#  'public',
#  'gate',
#  'week',
#  'time',
#  'implementation',
#  'rejected',
#  'overture',
#  'wanted',
#  'once.the',
#  'confronted',
#  'attend',
#  "''",
#  'officials',
#  'cordoned',
#  'ict',
#  'bhaban',
#  'building',
#  'three-point',
#  'ordering',
#  'ju',
#  'audio',
#  'heard',
#  'derogatory',
#  'comments',
#  'disseminated.on',
#  'hospitalized',
#  'nine',
#  'fell',
#  'sick',
#  'sit',
#  'refused',
#  'join',
#  'cause.the',
#  'today',
#  'protested',
#  'offensive',
#  'clip',
#  'residence.meanwhile',
#  'ensuring',
#  'strike',
#  'accountability',
#  'involved',
#  'also',
#  'persona',
#  'non',
#  'grata',
#  'filed',
#  'case',
#  'unnamed',
#  'resign',
#  'jan',
#  'program',
#  'removed',
#  'twenty-four',
#  'hunger',
#  '[']

# %%
vector = model.wv['student']

# Most similar words
similar = model.wv.most_similar('zafrin')

# %%
similar
# Out:
# [('day', 0.35697901248931885),
#  ('discussions', 0.3162936568260193),
#  ('dipu', 0.2712607979774475),
#  ('five-member', 0.262652724981308),
#  ('financial', 0.2544997036457062),
#  ('hall', 0.25304684042930603),
#  ('ordering', 0.2526407539844513),
#  ('team', 0.2514095902442932),
#  ('action', 0.2443370521068573),
#  ('sylhet', 0.23455235362052917)]
